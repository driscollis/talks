# %% [markdown]
# # Textual-cogs
#
# ## Mike Driscoll
#
# Source code: [https://github.com/driscollis/textual-cogs](https://github.com/driscollis/textual-cogs)

# %% [markdown]
# ## What is Textual?
#
# ![Alt text](posting.PNG)

# %% [markdown]
# ## What is textual-cogs
#
# ![Alt Text](textual_cogs_demo_0.0.5.gif)

# %% [markdown]
# ## Demo App

# %%
from textual.app import App
from textual.app import App, ComposeResult

from textual_cogs.dialogs import MessageDialog
from textual_cogs import icons


class DialogApp(App):
    def on_mount(self) -> ComposeResult:
        def my_callback(value: None | bool) -> None:
            self.exit()

        self.push_screen(
            MessageDialog(
                "What is your favorite language?",
                icon=icons.ICON_QUESTION,
                title="Warning",
            ),
            my_callback,
        )


if __name__ == "__main__":
    app = DialogApp()
    app.run()

# %% [markdown]
# ## Questions?
#
# [https://github.com/driscollis/textual-cogs](https://github.com/driscollis/textual-cogs)
