# %% [markdown]
# # Python Type Hinting Tooling
#
# ## Mike Driscoll

# %% [markdown]
# ## What are Type Hints?

# %%
def addition(a: int, b: int) -> int:
    return a + b

# %% [markdown]
# ## Type Checker Roundup
#
# - mypy by Dropbox
# - PyRight by Microsoft
# - ty by Astral / OpenAI
# - Pyrefly by Meta
# - Zuban by David Halter, the author of the widely-used Jedi autocompletion library

# %% [markdown]
# ## Type Checker Release Dates
#
# - Mypy 0.1.0 (Initial Public Release): December 8, 2014
# - Pyright - March 21, 2019
# - ty (Initial beta): December 2025
# - Pyrefly (Initial beta): November 17 2025 (or stable 1.0.0 May 12 2026)
# - Zuban (Beta 0.1.0): October 10, 2025

# %% [markdown]
# ## Benchmarks
#
# [Type Checker Timing Benchmarks](https://python-type-checking.com/typecheck_benchmark/)

# %% [markdown]
# ## Questions
